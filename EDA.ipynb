# %%
import pandas as pd
df_sales = pd.read_csv("superstore_sales_data.csv")
df_sales.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  2017-08-11  2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156  2017-08-11  2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688  2017-12-06         NaN    Second Class    DV-13045
# 3       4  US-2016-108966  2016-11-10         NaN  Standard Class    SO-20335
# 4       5  US-2016-108966  2016-11-10         NaN  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df_sales.groupby('Region')['Sales'].sum().sort_values(ascending=False)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
df_sales.groupby('Category')['Sales'].sum().sort_values(ascending=False)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
df_sales.groupby('Order Month')['Sales'].sum().sort_values(ascending=False)
# Out:
# Order Month
# February     103951.1600
# August       100560.3526
# January       90957.9824
# March         71788.6906
# November      68274.3135
# September     66582.3650
# April         65094.9490
# December      64819.3662
# May           64277.0788
# October       62563.7830
# July          62393.9465
# June          51099.1360
# Name: Sales, dtype: float64

# %%
import seaborn as sns
sns.barplot(x='Segment', y='Sales', data=df_sales)
# Out:
# <Axes: xlabel='Segment', ylabel='Sales'>
